# %%
print("hello")
# Out:
# hello

# %%
s={1,2,3,6,4,5,4,5,4}
for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
st={1,2,3,45,5,6,("geosns")}
st.add(28)
st.update((39,26,74))
print(st)
# Out:
# {1, 2, 3, 5, 6, 74, 26, 28, 39, 45, 'geosns'}

# %%
st={1,23,4,5,6,}
st.add((2,3,4,5,66))
print(st)
# st.add([8,6,4,3])
print(st)
st.update((8,6,89,0))
print(st)
# Out:
# {1, 4, 5, 6, 23, (2, 3, 4, 5, 66)}
# {1, 4, 5, 6, 23, (2, 3, 4, 5, 66)}
# {0, 1, 4, 5, 6, 8, 23, 89, (2, 3, 4, 5, 66)}

# %%
s={1,23,4,5,6,8}
s1 = {4,45,496,56}
print(s.union(s1))
print("union",s|s1)
print("intersection",s&s1)
print("difference",s-s1)
print("symmetric difference",s^s1)
# Out:
# union {1, 4, 5, 6, 8, 45, 496, 23, 56}
# intersection {4}
# difference {1, 5, 6, 8, 23}
# symmetric difference {1, 5, 6, 8, 45, 496, 23, 56}
